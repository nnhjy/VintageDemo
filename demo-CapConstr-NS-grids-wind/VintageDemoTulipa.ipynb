# %% [markdown]
# # Setup workflow environment

# %%
using Pkg; Pkg.activate(dirname(Base.current_project()))

import TulipaIO as TIO
import TulipaEnergyModel as TEM
using DuckDB
using DataFrames

# For Win. system to fix the KaTex parse error in Jupyter Notebook
Base.show(stdout, ::MIME"text/latex", df::DataFrame) = show(stdout, MIME("text/plain"), df)

#= For utility functions
    - print_annual_total_prod(DBconnection, years...)
    - inv_cost, fom_cost, var_cost = objective_terms_value(TulipaProblem, DBconnection)
    - annual_flows_between_assets(DBconnection, from_asset_term, to_asset_term)
=#
include("../src/util_analysis.jl");
# Out:
#   Activating project at `c:\ModellingRepos\VintageDemo`

# %% [markdown]
# # Multi-year investment model instances

# %% [markdown]
# - Milestone years: 2030, 2040 and 2050.
# - The system has 30GW initial wind capacity built in 2025, the model can choose to invest in wind in three milestone years: 2030, 2040, 2050.
# - unused tables: `flow-both.csv`, `flows-profiles.csv`

# %% [markdown]
# ## Instance 1. No technology vintage of units

# %% [markdown]
# > Note: the `output_dir` must exist/(be created) beforehand

# %% [markdown]
# ### 1.1 Build and run the model instance

# %%
# Define and build the input output directories
input_dir = "model-instance-Tulipa/input-1-no-vintage"
output_dir = joinpath(@__DIR__, "model-instance-Tulipa/output-1-no-vintage")

# Always build a new result directory
rm(output_dir, force=true, recursive=true) 
mkdir(output_dir);

# Create the connection and prepare input data
connection_no_vintage = DBInterface.connect(DuckDB.DB)
TIO.read_csv_folder(connection_no_vintage, input_dir)
TEM.populate_with_defaults!(connection_no_vintage)

# Run the model instance
multiyear_no_vintage = TEM.run_scenario(
    connection_no_vintage;
    optimizer_parameters = Dict("output_flag" => true), # TEM.default_parameters(HiGHS.Optimizer): Dict("output_flag" => false)
    output_folder = output_dir, 
    # model_file_name = joinpath(output_dir, "model.lp"),
    show_log=true,
    # To record solving time. 
    # Always run with this option in a new or restarted kernel to ensure the time is dedicated to this solve only.
    log_file = joinpath(@__DIR__, "model-instance-Tulipa/model-log_1-no-vintage.txt")
)
# Out:
# Running HiGHS 1.14.0 (git hash: 7df0786de3): Copyright (c) 2026 under Apache 2.0 license terms
# Using BLAS: blastrampoline-5
# MIP has 341640 rows; 315363 cols; 683271 nonzeros; 3 integer variables (0 binary)
# Coefficient ranges:
#   Matrix  [2e-04, 1e+00]
#   Cost    [1e-03, 3e+03]
#   Bound   [1e+02, 2e+02]
#   RHS     [5e-03, 1e+02]
# Presolving model
# 26277 rows, 112441 cols, 164989 nonzeros 0s
# 25202 rows, 111366 cols, 161103 nonzeros 2s
# Presolve reductions: rows 25202(-316438); columns 111366(-203997); nonzeros 161103(-522168)
#
# Solving MIP model with:
#    25202 rows
#    111366 cols (0 binary, 3 integer, 0 implied int., 111363 continuous, 0 domain fixed)
#    161103 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2069191.811821     Large        0      0      0         0     2.9s
#  R       0       0         0   0.00%   1249318.09584   1249318.595403     0.00%        0      0      0     37217    10.3s
#          1       0         1 100.00%   1249318.09584   1249318.595403     0.00%        0      0      0     37217    10.6s
#
# Solving report
#   Status            Optimal
#   Primal bound      1249318.5954
#   Dual bound        1249318.09584
#   Gap               4e-05% (tolerance: 0.01%)
#   P-D integral      5.4474851564
#   Solution status   feasible
#                     1249318.5954 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            10.64
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     37217
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# LP has 341640 rows; 315363 cols; 683271 nonzeros
# Coefficient ranges:
#   Matrix  [2e-04, 1e+00]
#   Cost    [1e-03, 3e+03]
#   Bound   [3e+01, 2e+02]
#   RHS     [5e-03, 1e+02]
# Presolving model
# 19072 rows, 19072 cols, 19072 nonzeros 0s
# 0 rows, 0 cols, 0 nonzeros 0s
# Presolve reductions: rows 0(-341640); columns 0(-315363); nonzeros 0(-683271) - Reduced to empty
# Performed postsolve
# Solving the original LP from the solution after postsolve
#
# Model status        : Optimal
# Objective value     :  1.2493185954e+06
# P-D objective error :  3.7403662806e-13
# HiGHS run time      :          1.16
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                          Time                    Allocations
#                                                                                                                                                 ───────────────────────   ────────────────────────
#                                                                Tot / % measured:                                                                      423h /   0.0%           7.65GiB /  67.6%
#
# Section                                                                                                                                 ncalls     time    %tot     avg     alloc    %tot      avg
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# solve_model!                                                                                                                                 1     119s   80.0%    119s    665MiB   12.6%   665MiB
#   total solver time                                                                                                                          1     118s   79.4%    118s    522MiB    9.9%   522MiB
# create_model!                                                                                                                                1    18.5s   12.4%   18.5s   2.99GiB   57.7%  2.99GiB
#   create_model                                                                                                                               1    18.4s   12.4%   18.4s   2.98GiB   57.7%  2.98GiB
#     add_expressions_to_constraints!                                                                                                          1    3.18s    2.1%   3.18s    523MiB    9.9%   523MiB
#       add_expression_terms_rep_period_constraints!                                                                                           7    1.66s    1.1%   237ms    245MiB    4.6%  35.0MiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method                                           1    488ms    0.3%   488ms    243MiB    4.6%   243MiB
#       add_expression_terms_inter_period_storage_constraints!                                                                                 1    434ms    0.3%   434ms   18.0MiB    0.3%  18.0MiB
#       add_expression_terms_inter_period_constraints!                                                                                         2    251ms    0.2%   125ms   9.44MiB    0.2%  4.72MiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_compact_efficiencies_vintage_method                                 1   32.3ms    0.0%  32.3ms    705KiB    0.0%   705KiB
#       add_expression_terms_accumulated_storage_intra_period_constraints!                                                                     1   20.5ms    0.0%  20.5ms   31.6KiB    0.0%  31.6KiB
#       add_expression_terms_rep_period_constraints! for min_incoming_flow_for_transport_flows                                                 1   19.6ms    0.0%  19.6ms   31.5KiB    0.0%  31.5KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method_investable_storage_with_binary            1   19.4ms    0.0%  19.4ms   31.9KiB    0.0%  31.9KiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method_non_investable_storage_with_binary        1   19.3ms    0.0%  19.3ms   32.0KiB    0.0%  32.0KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method_non_investable_storage_with_binary        1   19.3ms    0.0%  19.3ms   32.0KiB    0.0%  32.0KiB
#       add_expression_terms_rep_period_constraints! for min_outgoing_flow_for_transport_flows_without_unit_commitment                         1   19.2ms    0.0%  19.2ms   31.9KiB    0.0%  31.9KiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_compact_profiles_vintage_method                                     1   19.0ms    0.0%  19.0ms   31.8KiB    0.0%  31.8KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method                                           1   18.9ms    0.0%  18.9ms   31.6KiB    0.0%  31.6KiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method_investable_storage_with_binary            1   18.7ms    0.0%  18.7ms   31.9KiB    0.0%  31.9KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method                                                           1   18.7ms    0.0%  18.7ms    675KiB    0.0%   675KiB
#       add_expression_terms_rep_period_constraints! for min_outgoing_flow_for_transport_vintage_flows                                         1   12.7ms    0.0%  12.7ms   33.0KiB    0.0%  33.0KiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method                                                           1   8.55ms    0.0%  8.55ms   2.82MiB    0.1%  2.82MiB
#       attach units_on expression to min_output_flow_with_unit_commitment                                                                     1   7.82ms    0.0%  7.82ms   14.2KiB    0.0%  14.2KiB
#       attach is_charging expression to min_incoming_flow_for_transport_flows                                                                 1   6.51ms    0.0%  6.51ms   11.8KiB    0.0%  11.8KiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method_investable_storage_with_binary                            1   6.46ms    0.0%  6.46ms   11.9KiB    0.0%  11.9KiB
#       attach units_on expression to max_ramp_with_unit_commitment                                                                            1   6.39ms    0.0%  6.39ms   11.7KiB    0.0%  11.7KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method_non_investable_storage_with_binary                        1   5.84ms    0.0%  5.84ms   11.9KiB    0.0%  11.9KiB
#       attach is_charging expression to capacity_outgoing_compact_profiles_vintage_method                                                     1   5.84ms    0.0%  5.84ms   11.8KiB    0.0%  11.8KiB
#       attach units_on expression to max_output_flow_with_basic_unit_commitment                                                               1   5.80ms    0.0%  5.80ms   11.8KiB    0.0%  11.8KiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method_non_investable_storage_with_binary                        1   5.62ms    0.0%  5.62ms   11.9KiB    0.0%  11.9KiB
#       attach is_charging expression to min_outgoing_flow_for_transport_flows_without_unit_commitment                                         1   5.61ms    0.0%  5.61ms   11.9KiB    0.0%  11.9KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method_investable_storage_with_binary                            1   5.49ms    0.0%  5.49ms   11.9KiB    0.0%  11.9KiB
#     add_capacity_constraints!                                                                                                                1    2.36s    1.6%   2.36s    747MiB   14.1%   747MiB
#     add_flow_variables!                                                                                                                      1    1.30s    0.9%   1.30s    534MiB   10.1%   534MiB
#     add_operational_cost_expressions!                                                                                                        1    1.12s    0.8%   1.12s    226MiB    4.3%   226MiB
#     add_consumer_constraints!                                                                                                                1    982ms    0.7%   982ms    393MiB    7.4%   393MiB
#     add_objective!                                                                                                                           1    664ms    0.4%   664ms    157MiB    3.0%   157MiB
#     add_ramping_constraints!                                                                                                                 1    556ms    0.4%   556ms   41.8MiB    0.8%  41.8MiB
#     add_investment_variables!                                                                                                                1    387ms    0.3%   387ms   31.8MiB    0.6%  31.8MiB
#     add_decommission_variables!                                                                                                              1    246ms    0.2%   246ms   25.5MiB    0.5%  25.5MiB
#     create_multi_year_expressions!                                                                                                           1    153ms    0.1%   153ms   7.74MiB    0.1%  7.74MiB
#     add_storage_constraints!                                                                                                                 1    107ms    0.1%   107ms   8.58MiB    0.2%  8.58MiB
#     prepare_objective_tables!                                                                                                                1   78.7ms    0.1%  78.7ms   3.33MiB    0.1%  3.33MiB
#     add_storage_variables!                                                                                                                   1   51.0ms    0.0%  51.0ms   2.60MiB    0.0%  2.60MiB
#     get_model_parameters!                                                                                                                    1   49.0ms    0.0%  49.0ms   2.37MiB    0.0%  2.37MiB
#     add_dc_power_flow_constraints!                                                                                                           1   36.5ms    0.0%  36.5ms   2.06MiB    0.0%  2.06MiB
#     add_shut_down_upper_bound_constraints!                                                                                                   1   28.4ms    0.0%  28.4ms   1.30MiB    0.0%  1.30MiB
#     add_energy_constraints!                                                                                                                  1   27.0ms    0.0%  27.0ms   1.30MiB    0.0%  1.30MiB
#     add_flows_relationships_constraints!                                                                                                     1   26.4ms    0.0%  26.4ms   1.30MiB    0.0%  1.30MiB
#     add_conditional_value_at_risk_variables!                                                                                                 1   20.6ms    0.0%  20.6ms   1.29MiB    0.0%  1.29MiB
#     add_storage_expressions!                                                                                                                 1   15.6ms    0.0%  15.6ms    674KiB    0.0%   674KiB
#     add_vintage_flow_variables!                                                                                                              1   15.1ms    0.0%  15.1ms    665KiB    0.0%   665KiB
#     add_transport_constraints!                                                                                                               1   14.5ms    0.0%  14.5ms    671KiB    0.0%   671KiB
#     add_vintage_flow_sum_constraints!                                                                                                        1   14.1ms    0.0%  14.1ms    669KiB    0.0%   669KiB
#     add_investment_group_constraints!                                                                                                        1   13.7ms    0.0%  13.7ms    666KiB    0.0%   666KiB
#     add_uc_logic_constraints!                                                                                                                1   13.5ms    0.0%  13.5ms    670KiB    0.0%   670KiB
#     add_start_up_upper_bound_constraints!                                                                                                    1   13.1ms    0.0%  13.1ms    666KiB    0.0%   666KiB
#     add_conversion_constraints!                                                                                                              1   12.2ms    0.0%  12.2ms    665KiB    0.0%   665KiB
#     add_unit_commitment_variables!                                                                                                           1   12.0ms    0.0%  12.0ms    662KiB    0.0%   662KiB
#     add_power_flow_variables!                                                                                                                1   11.2ms    0.0%  11.2ms    662KiB    0.0%   662KiB
#     add_scenario_tail_excess_expressions!                                                                                                    1   1.26ms    0.0%  1.26ms   3.34KiB    0.0%  3.34KiB
#     add_scenario_tail_excess_constraints!                                                                                                    1    608μs    0.0%   608μs      544B    0.0%     544B
#     add_start_up_and_shut_down_variables!                                                                                                    1   68.9μs    0.0%  68.9μs   4.22KiB    0.0%  4.22KiB
# save_solution!                                                                                                                               1    5.53s    3.7%   5.53s    829MiB   15.7%   829MiB
#   compute_dual_variables                                                                                                                     1    2.10s    1.4%   2.10s   64.8MiB    1.2%  64.8MiB
# create EnergyProblem from connection                                                                                                         1    5.32s    3.6%   5.32s    737MiB   13.9%   737MiB
#   create_internal_structure                                                                                                                  1    4.48s    3.0%   4.48s    694MiB   13.1%   694MiB
#     validate data                                                                                                                            1    1.67s    1.1%   1.67s    120MiB    2.3%   120MiB
#       no duplicate rows                                                                                                                      1    302ms    0.2%   302ms   19.1MiB    0.4%  19.1MiB
#       valid schema's oneOf constraints                                                                                                       1    243ms    0.2%   243ms   20.9MiB    0.4%  20.9MiB
#       consumer unit commitment used as bids has right data                                                                                   1    231ms    0.2%   231ms   32.0MiB    0.6%  32.0MiB
#       stochastic scenario probabilities sum to 1                                                                                             1    142ms    0.1%   142ms   8.70MiB    0.2%  8.70MiB
#       group consistency between tables                                                                                                       1    123ms    0.1%   123ms   13.3MiB    0.3%  13.3MiB
#       has all tables and columns                                                                                                             1    103ms    0.1%   103ms   2.75MiB    0.1%  2.75MiB
#       data consistency for aggregated vintage method                                                                                         1    102ms    0.1%   102ms   4.41MiB    0.1%  4.41MiB
#       model_parameters discount_year is valid                                                                                                1   64.4ms    0.0%  64.4ms   3.07MiB    0.1%  3.07MiB
#       consistency between flow_commission and asset_both                                                                                     1   54.3ms    0.0%  54.3ms   1.99MiB    0.0%  1.99MiB
#       check DC OPF data                                                                                                                      1   52.4ms    0.0%  52.4ms   2.04MiB    0.0%  2.04MiB
#       consistency between asset_commission and asset_both                                                                                    1   51.0ms    0.0%  51.0ms   2.42MiB    0.0%  2.42MiB
#       consumer assets use the aggregated vintage method                                                                                      1   38.3ms    0.0%  38.3ms   1.53MiB    0.0%  1.53MiB
#       investable storage assets using binary method should have investment limit > 0                                                         1   34.6ms    0.0%  34.6ms   2.02MiB    0.0%  2.02MiB
#       commodity_price profiles require commodity_price > 0                                                                                   1   31.7ms    0.0%  31.7ms   1.58MiB    0.0%  1.58MiB
#       flow_both only contain transport flows                                                                                                 1   30.8ms    0.0%  30.8ms   1.78MiB    0.0%  1.78MiB
#       consistency between investable and asset_both                                                                                          1   29.4ms    0.0%  29.4ms   1.37MiB    0.0%  1.37MiB
#       only transport flows are investable                                                                                                    1   26.7ms    0.0%  26.7ms   1.29MiB    0.0%  1.29MiB
#       model_parameters has exactly one row                                                                                                   1   7.17ms    0.0%  7.17ms   92.9KiB    0.0%  92.9KiB
#     create_lowest_resolution_table                                                                                                           1    1.38s    0.9%   1.38s    549MiB   10.4%   549MiB
#       append t_lowest_all_flows rows                                                                                                         1    689ms    0.5%   689ms    275MiB    5.2%   275MiB
#       append t_lowest_all rows                                                                                                               1    665ms    0.4%   665ms    273MiB    5.2%   273MiB
#       append t_lowest_flows_relationship rows                                                                                                1    665μs    0.0%   665μs   2.52KiB    0.0%  2.52KiB
#       append t_lowest_flows_conversion_balance rows                                                                                          1    506μs    0.0%   506μs   2.53KiB    0.0%  2.53KiB
#     create_highest_resolution_table                                                                                                          1    537ms    0.4%   537ms   8.31KiB    0.0%  8.31KiB
#     create_merged_tables                                                                                                                     1    437ms    0.3%   437ms   6.84KiB    0.0%  6.84KiB
#     create_unrolled_partition_tables                                                                                                         1    337ms    0.2%   337ms   16.3MiB    0.3%  16.3MiB
#   prepare_profiles_structure                                                                                                                 1    568ms    0.4%   568ms   41.8MiB    0.8%  41.8MiB
#   compute_constraints_indices                                                                                                                1    159ms    0.1%   159ms   1.59MiB    0.0%  1.59MiB
#   compute_variables_indices                                                                                                                  1    103ms    0.1%   103ms   39.5KiB    0.0%  39.5KiB
# export_solution_to_csv_files                                                                                                                 1    467ms    0.3%   467ms   5.17MiB    0.1%  5.17MiB
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# EnergyProblem:
#   - Model created!
#     - Number of variables: 315363
#     - Number of constraints for variable bounds: 315363
#     - Number of structural constraints: 341640
#   - Model solved!
#     - Termination status: OPTIMAL
#     - Objective value: 1.2493185954028412e6
#     - Objective breakdown:
#       - assets_fixed_cost_aggregated_vintage_method: 175612.17023311552
#       - assets_fixed_cost_compact_vintage_method: 0.0
#       - assets_investment_cost: 395982.5636673817
#       - flows_fixed_cost: 0.0
#       - flows_investment_cost: 0.0
#       - flows_operational_cost: 677723.8615028982
#       - storage_assets_energy_fixed_cost: 0.0
#       - storage_assets_energy_investment_cost: 0.0
#       - units_on_operational_cost: 0.0
#       - vintage_flows_operational_cost: 0.0

# %% [markdown]
# ### 1.2 Key results

# %% [markdown]
# #### Capacity

# %% [markdown]
# Check the "initial capacity"
#
# - in this case, we will not be able to differentiate units built in other years (than milestone years),
# - they will simply be considered the same as the units built in the milestone year.

# %%
# initial wind capacity
filter(row -> row.asset=="wind", TIO.get_table(connection_no_vintage, "asset_both"))
# Out:
# 3×6 DataFrame
#  Row │ asset   milestone_year  commission_year  decommissionable  initial_unit ⋯
#      │ String  Int32           Int32            Bool              Float64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ wind              2030             2030             false           30. ⋯
#    2 │ wind              2040             2040             false           30.
#    3 │ wind              2050             2050             false           30.
#                                                                2 columns omitted

# %%
# invested capacity
filter(row -> row.asset=="wind", TIO.get_table(connection_no_vintage, "var_assets_investment"))
# Out:
# 3×7 DataFrame
#  Row │ id     asset   milestone_year  investment_integer  capacity  investment ⋯
#      │ Int64  String  Int32           Bool                Float64   Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1  wind              2030                true       1.0           1 ⋯
#    2 │     2  wind              2040                true       1.0           1
#    3 │     3  wind              2050                true       1.0           2
#                                                                2 columns omitted

# %% [markdown]
# #### Annual productions & total system cost

# %%
print_annual_total_prod(connection_no_vintage, 2030, 2040, 2050)

total_cost = multiyear_no_vintage.objective_value
println("Total system cost: $(round(total_cost/1000, digits=2)) Billion €")

inv_cost, fixed_om_cost, variable_om_cost = objective_terms_value(multiyear_no_vintage, connection_no_vintage)
println(
    "\t investment: $(round(inv_cost/1000, digits=2)) Billion € \n", 
    "\t fixed O&M: $(round(fixed_om_cost/1000, digits=2)) Billion € \n",
    "\t variable O&M: $(round(variable_om_cost/1000, digits=2)) Billion €"
)
println(
    "Total system cost ≈ investment + fixed O&M + variable O&M: ", 
    total_cost ≈ inv_cost + fixed_om_cost + variable_om_cost
)
# @assert total_cost ≈ inv_cost + fixed_om_cost + variable_om_cost
# Out:
# 2030s
# 	 wind prodution: 665.62 TWh p.a.
# 	 market supply: 313.29 TWh p.a.
# 2040s
# 	 wind prodution: 1413.94 TWh p.a.
# 	 market supply: 516.3 TWh p.a.
# 2050s
# 	 wind prodution: 1489.76 TWh p.a.
# 	 market supply: 753.49 TWh p.a.
# Total system cost: 1249.32 Billion €
# 	 investment: 395.98 Billion €
# 	 fixed O&M: 175.61 Billion €
# 	 variable O&M: 677.72 Billion €
# Total system cost ≈ investment + fixed O&M + variable O&M: true

# %% [markdown]
# ## Instance 2. Explicit technology vintage of units - standard method
#
# - Difference from **Instance 1**: `asset.csv`, `asset-milestone.csv`, `asset-commission.csv`, `asset-both`, `assets-profiles.csv`, `flow*.csv`
# - In any milestone year, only the tech. vintage of the same year is available for investment (explicitly regulated by setting the `investable` parameter in `asset-milestone.csv`)

# %% [markdown]
# ### 2.1 Build and run the model instance

# %%
# Define and build the input output directories
input_dir = "model-instance-Tulipa/input-2-vintage-standard"
output_dir = joinpath(@__DIR__, "model-instance-Tulipa/output-2-vintage-standard")

# Always build a new result directory
rm(output_dir, force=true, recursive=true) 
mkdir(output_dir);

# Create the connection and prepare input data
connection_vintage_standard = DBInterface.connect(DuckDB.DB)
TIO.read_csv_folder(connection_vintage_standard, input_dir)
TEM.populate_with_defaults!(connection_vintage_standard)

# Run the model instance
multiyear_vintage_standard = TEM.run_scenario(
    connection_vintage_standard;
    optimizer_parameters = Dict("output_flag" => true), # TEM.default_parameters(HiGHS.Optimizer): Dict("output_flag" => false)
    output_folder = output_dir, 
    # model_file_name = joinpath(output_dir, "model.lp"),
    show_log=true,
    # To record solving time. 
    # Always run with this option in a new or restarted kernel to ensure the time is dedicated to this solve only.
    log_file = joinpath(@__DIR__, "model-instance-Tulipa/model-log_2-vintage-standard.txt")
)
# Out:
# Running HiGHS 1.14.0 (git hash: 7df0786de3): Copyright (c) 2026 under Apache 2.0 license terms
# Using BLAS: blastrampoline-5
# MIP has 420480 rows; 788403 cols; 1629351 nonzeros; 3 integer variables (0 binary)
# Coefficient ranges:
#   Matrix  [3e-06, 1e+00]
#   Cost    [1e-03, 3e+03]
#   Bound   [1e+02, 2e+02]
#   RHS     [4e-04, 1e+02]
# Presolving model
# 236511 rows, 630669 cols, 1156203 nonzeros 3s
# 229371 rows, 614281 cols, 1123604 nonzeros 8s
# Presolve reductions: rows 229371(-191109); columns 614281(-174122); nonzeros 1123604(-505747)
#
# Solving MIP model with:
#    229371 rows
#    614281 cols (0 binary, 3 integer, 0 implied int., 614278 continuous, 0 domain fixed)
#    1123604 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2370346.264984     Large        0      0      0         0    18.6s
#  R       0       0         0   0.00%   1220538.61438   1220538.750713     0.00%        0      0      0    324033   201.3s
#          1       0         1 100.00%   1220538.61438   1220538.750713     0.00%        0      0      0    324033   202.2s
#
# Solving report
#   Status            Optimal
#   Primal bound      1220538.75071
#   Dual bound        1220538.61438
#   Gap               1.1e-05% (tolerance: 0.01%)
#   P-D integral      174.415272184
#   Solution status   feasible
#                     1220538.75071 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            202.21
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     324033
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# LP has 420480 rows; 788403 cols; 1629351 nonzeros
# Coefficient ranges:
#   Matrix  [3e-06, 1e+00]
#   Cost    [1e-03, 3e+03]
#   Bound   [1e+02, 2e+02]
#   RHS     [4e-04, 1e+02]
# Presolving model
# 236511 rows, 630666 cols, 1103652 nonzeros 2s
# Dependent equations search running on 157680 equations with time limit of 1000.00s
# Dependent equations search removed 0 rows and 0 nonzeros in 0.03s (limit = 1000.00s)
# 236511 rows, 630666 cols, 1103652 nonzeros 3s
# Presolve reductions: rows 236511(-183969); columns 630666(-157737); nonzeros 1103652(-525699)
# Solving the presolved LP
# Using dual simplex solver
#   Iteration        Objective     Infeasibilities num(sum)
#           0     6.1947502796e+05 Pr: 157680(5.1524e+06) 4.8s
#      105452     7.6789117390e+05 Pr: 122669(2.04357e+06); Du: 0(0.000909694) 9.8s
#      198564     1.0477526636e+06 Pr: 70611(640512); Du: 0(0.00136722) 14.9s
#      284180     1.2172373458e+06 Pr: 10765(23176.3); Du: 0(0.00122992) 19.9s
#      295541     1.2205387507e+06 Pr: 0(0); Du: 0(1.10393e-12) 20.6s
#
# Performed postsolve
# Solving the original LP from the solution after postsolve
#
# Model status        : Optimal
# Simplex   iterations: 295541
# Objective value     :  1.2205387507e+06
# P-D objective error :  5.6083578790e-13
# HiGHS run time      :         22.02
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                          Time                    Allocations
#                                                                                                                                                 ───────────────────────   ────────────────────────
#                                                                Tot / % measured:                                                                      423h /   0.0%           16.1GiB /  74.9%
#
# Section                                                                                                                                 ncalls     time    %tot     avg     alloc    %tot      avg
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# solve_model!                                                                                                                                 2     669s   89.8%    334s   1.56GiB   13.0%   798MiB
#   total solver time                                                                                                                          2     668s   89.7%    334s   1.42GiB   11.8%   726MiB
# save_solution!                                                                                                                               2    33.6s    4.5%   16.8s   1.84GiB   15.3%   941MiB
#   compute_dual_variables                                                                                                                     2    24.2s    3.2%   12.1s   64.8MiB    0.5%  32.4MiB
# create_model!                                                                                                                                2    31.4s    4.2%   15.7s   7.24GiB   60.2%  3.62GiB
#   create_model                                                                                                                               2    31.4s    4.2%   15.7s   7.24GiB   60.2%  3.62GiB
#     add_expressions_to_constraints!                                                                                                          2    6.56s    0.9%   3.28s   1.30GiB   10.8%   665MiB
#       add_expression_terms_rep_period_constraints!                                                                                          14    3.88s    0.5%   277ms    607MiB    4.9%  43.3MiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method                                           2    1.17s    0.2%   586ms    682MiB    5.5%   341MiB
#       add_expression_terms_inter_period_storage_constraints!                                                                                 2    454ms    0.1%   227ms   18.0MiB    0.1%  9.02MiB
#       add_expression_terms_inter_period_constraints!                                                                                         4    302ms    0.0%  75.4ms   9.49MiB    0.1%  2.37MiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method_non_investable_storage_with_binary        2   57.0ms    0.0%  28.5ms   64.0KiB    0.0%  32.0KiB
#       add_expression_terms_rep_period_constraints! for min_outgoing_flow_for_transport_flows_without_unit_commitment                         2   53.5ms    0.0%  26.8ms   63.8KiB    0.0%  31.9KiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method_investable_storage_with_binary            2   53.5ms    0.0%  26.7ms   63.8KiB    0.0%  31.9KiB
#       add_expression_terms_rep_period_constraints! for min_incoming_flow_for_transport_flows                                                 2   51.0ms    0.0%  25.5ms   63.1KiB    0.0%  31.5KiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_compact_profiles_vintage_method                                     2   50.6ms    0.0%  25.3ms   63.6KiB    0.0%  31.8KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method_investable_storage_with_binary            2   50.6ms    0.0%  25.3ms   63.8KiB    0.0%  31.9KiB
#       add_expression_terms_accumulated_storage_intra_period_constraints!                                                                     2   49.8ms    0.0%  24.9ms   63.3KiB    0.0%  31.6KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method_non_investable_storage_with_binary        2   49.6ms    0.0%  24.8ms   64.0KiB    0.0%  32.0KiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_compact_efficiencies_vintage_method                                 2   49.1ms    0.0%  24.5ms    745KiB    0.0%   372KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method                                           2   47.9ms    0.0%  24.0ms   63.2KiB    0.0%  31.6KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method                                                           2   26.3ms    0.0%  13.1ms    689KiB    0.0%   345KiB
#       add_expression_terms_rep_period_constraints! for min_outgoing_flow_for_transport_vintage_flows                                         2   25.5ms    0.0%  12.7ms   66.1KiB    0.0%  33.0KiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method                                                           2   17.8ms    0.0%  8.91ms   6.84MiB    0.1%  3.42MiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method_non_investable_storage_with_binary                        2   15.6ms    0.0%  7.79ms   23.8KiB    0.0%  11.9KiB
#       attach units_on expression to min_output_flow_with_unit_commitment                                                                     2   15.2ms    0.0%  7.59ms   28.5KiB    0.0%  14.2KiB
#       attach is_charging expression to min_incoming_flow_for_transport_flows                                                                 2   13.1ms    0.0%  6.55ms   23.5KiB    0.0%  11.8KiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method_investable_storage_with_binary                            2   12.8ms    0.0%  6.39ms   23.8KiB    0.0%  11.9KiB
#       attach is_charging expression to min_outgoing_flow_for_transport_flows_without_unit_commitment                                         2   12.7ms    0.0%  6.37ms   23.7KiB    0.0%  11.9KiB
#       attach units_on expression to max_output_flow_with_basic_unit_commitment                                                               2   12.4ms    0.0%  6.20ms   23.6KiB    0.0%  11.8KiB
#       attach units_on expression to max_ramp_with_unit_commitment                                                                            2   12.2ms    0.0%  6.10ms   23.3KiB    0.0%  11.7KiB
#       attach is_charging expression to capacity_outgoing_compact_profiles_vintage_method                                                     2   11.4ms    0.0%  5.68ms   23.7KiB    0.0%  11.8KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method_non_investable_storage_with_binary                        2   11.3ms    0.0%  5.64ms   23.8KiB    0.0%  11.9KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method_investable_storage_with_binary                            2   11.0ms    0.0%  5.48ms   23.8KiB    0.0%  11.9KiB
#     add_capacity_constraints!                                                                                                                2    4.83s    0.6%   2.42s   1.70GiB   14.1%   869MiB
#     add_flow_variables!                                                                                                                      2    4.32s    0.6%   2.16s   1.79GiB   14.9%   916MiB
#     add_operational_cost_expressions!                                                                                                        2    3.57s    0.5%   1.78s    758MiB    6.2%   379MiB
#     add_consumer_constraints!                                                                                                                2    1.95s    0.3%   976ms    832MiB    6.8%   416MiB
#     add_objective!                                                                                                                           2    1.25s    0.2%   623ms    445MiB    3.6%   222MiB
#     add_ramping_constraints!                                                                                                                 2    567ms    0.1%   284ms   41.9MiB    0.3%  20.9MiB
#     add_investment_variables!                                                                                                                2    388ms    0.1%   194ms   31.8MiB    0.3%  15.9MiB
#     add_decommission_variables!                                                                                                              2    246ms    0.0%   123ms   25.5MiB    0.2%  12.7MiB
#     create_multi_year_expressions!                                                                                                           2    170ms    0.0%  85.0ms   7.84MiB    0.1%  3.92MiB
#     add_storage_constraints!                                                                                                                 2    125ms    0.0%  62.7ms   8.61MiB    0.1%  4.30MiB
#     prepare_objective_tables!                                                                                                                2    112ms    0.0%  55.8ms   3.35MiB    0.0%  1.68MiB
#     add_storage_variables!                                                                                                                   2   52.8ms    0.0%  26.4ms   2.61MiB    0.0%  1.30MiB
#     get_model_parameters!                                                                                                                    2   49.7ms    0.0%  24.8ms   2.38MiB    0.0%  1.19MiB
#     add_dc_power_flow_constraints!                                                                                                           2   41.6ms    0.0%  20.8ms   2.07MiB    0.0%  1.04MiB
#     add_shut_down_upper_bound_constraints!                                                                                                   2   33.1ms    0.0%  16.5ms   1.31MiB    0.0%   669KiB
#     add_energy_constraints!                                                                                                                  2   30.0ms    0.0%  15.0ms   1.30MiB    0.0%   667KiB
#     add_flows_relationships_constraints!                                                                                                     2   29.4ms    0.0%  14.7ms   1.31MiB    0.0%   671KiB
#     add_conditional_value_at_risk_variables!                                                                                                 2   20.7ms    0.0%  10.3ms   1.29MiB    0.0%   662KiB
#     add_storage_expressions!                                                                                                                 2   18.4ms    0.0%  9.22ms    684KiB    0.0%   342KiB
#     add_vintage_flow_variables!                                                                                                              2   16.7ms    0.0%  8.34ms    671KiB    0.0%   335KiB
#     add_transport_constraints!                                                                                                               2   16.3ms    0.0%  8.13ms    682KiB    0.0%   341KiB
#     add_vintage_flow_sum_constraints!                                                                                                        2   16.2ms    0.0%  8.11ms    674KiB    0.0%   337KiB
#     add_investment_group_constraints!                                                                                                        2   15.4ms    0.0%  7.68ms    671KiB    0.0%   336KiB
#     add_uc_logic_constraints!                                                                                                                2   15.3ms    0.0%  7.66ms    680KiB    0.0%   340KiB
#     add_start_up_upper_bound_constraints!                                                                                                    2   15.0ms    0.0%  7.49ms    674KiB    0.0%   337KiB
#     add_conversion_constraints!                                                                                                              2   13.1ms    0.0%  6.57ms    668KiB    0.0%   334KiB
#     add_unit_commitment_variables!                                                                                                           2   12.0ms    0.0%  6.02ms    664KiB    0.0%   332KiB
#     add_power_flow_variables!                                                                                                                2   11.2ms    0.0%  5.61ms    664KiB    0.0%   332KiB
#     add_scenario_tail_excess_expressions!                                                                                                    2   2.88ms    0.0%  1.44ms   6.69KiB    0.0%  3.34KiB
#     add_scenario_tail_excess_constraints!                                                                                                    2    959μs    0.0%   479μs   1.06KiB    0.0%     544B
#     add_start_up_and_shut_down_variables!                                                                                                    2   83.2μs    0.0%  41.6μs   8.44KiB    0.0%  4.22KiB
# create EnergyProblem from connection                                                                                                         2    9.47s    1.3%   4.74s   1.38GiB   11.5%   706MiB
#   create_internal_structure                                                                                                                  2    8.26s    1.1%   4.13s   1.33GiB   11.1%   683MiB
#     create_lowest_resolution_table                                                                                                           2    3.34s    0.4%   1.67s   1.19GiB    9.9%   611MiB
#       append t_lowest_all_flows rows                                                                                                         2    1.99s    0.3%   995ms    612MiB    5.0%   306MiB
#       append t_lowest_all rows                                                                                                               2    1.32s    0.2%   659ms    609MiB    5.0%   305MiB
#       append t_lowest_flows_relationship rows                                                                                                2   1.32ms    0.0%   658μs   5.03KiB    0.0%  2.52KiB
#       append t_lowest_flows_conversion_balance rows                                                                                          2   1.06ms    0.0%   530μs   5.06KiB    0.0%  2.53KiB
#     validate data                                                                                                                            2    1.74s    0.2%   872ms    121MiB    1.0%  60.3MiB
#       no duplicate rows                                                                                                                      2    322ms    0.0%   161ms   19.1MiB    0.2%  9.57MiB
#       valid schema's oneOf constraints                                                                                                       2    247ms    0.0%   124ms   21.0MiB    0.2%  10.5MiB
#       consumer unit commitment used as bids has right data                                                                                   2    231ms    0.0%   116ms   32.0MiB    0.3%  16.0MiB
#       stochastic scenario probabilities sum to 1                                                                                             2    143ms    0.0%  71.5ms   8.71MiB    0.1%  4.35MiB
#       has all tables and columns                                                                                                             2    134ms    0.0%  67.0ms   2.82MiB    0.0%  1.41MiB
#       group consistency between tables                                                                                                       2    126ms    0.0%  62.9ms   13.3MiB    0.1%  6.66MiB
#       data consistency for aggregated vintage method                                                                                         2    107ms    0.0%  53.5ms   4.42MiB    0.0%  2.21MiB
#       model_parameters discount_year is valid                                                                                                2   65.2ms    0.0%  32.6ms   3.07MiB    0.0%  1.53MiB
#       consistency between flow_commission and asset_both                                                                                     2   56.8ms    0.0%  28.4ms   2.00MiB    0.0%  1.00MiB
#       check DC OPF data                                                                                                                      2   53.3ms    0.0%  26.7ms   2.04MiB    0.0%  1.02MiB
#       consistency between asset_commission and asset_both                                                                                    2   52.7ms    0.0%  26.3ms   2.42MiB    0.0%  1.21MiB
#       consumer assets use the aggregated vintage method                                                                                      2   38.6ms    0.0%  19.3ms   1.53MiB    0.0%   784KiB
#       investable storage assets using binary method should have investment limit > 0                                                         2   35.8ms    0.0%  17.9ms   2.02MiB    0.0%  1.01MiB
#       commodity_price profiles require commodity_price > 0                                                                                   2   34.3ms    0.0%  17.2ms   1.59MiB    0.0%   812KiB
#       flow_both only contain transport flows                                                                                                 2   31.5ms    0.0%  15.8ms   1.78MiB    0.0%   913KiB
#       consistency between investable and asset_both                                                                                          2   30.2ms    0.0%  15.1ms   1.37MiB    0.0%   703KiB
#       only transport flows are investable                                                                                                    2   27.8ms    0.0%  13.9ms   1.29MiB    0.0%   661KiB
#       model_parameters has exactly one row                                                                                                   2   7.50ms    0.0%  3.75ms   94.5KiB    0.0%  47.2KiB
#     create_highest_resolution_table                                                                                                          2    1.22s    0.2%   610ms   16.6KiB    0.0%  8.31KiB
#     create_merged_tables                                                                                                                     2    1.19s    0.2%   597ms   13.7KiB    0.0%  6.84KiB
#     create_unrolled_partition_tables                                                                                                         2    610ms    0.1%   305ms   16.4MiB    0.1%  8.21MiB
#   prepare_profiles_structure                                                                                                                 2    585ms    0.1%   293ms   43.8MiB    0.4%  21.9MiB
#   compute_variables_indices                                                                                                                  2    320ms    0.0%   160ms   79.0KiB    0.0%  39.5KiB
#   compute_constraints_indices                                                                                                                2    311ms    0.0%   156ms   1.77MiB    0.0%   906KiB
# export_solution_to_csv_files                                                                                                                 2    1.49s    0.2%   747ms   5.30MiB    0.0%  2.65MiB
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# EnergyProblem:
#   - Model created!
#     - Number of variables: 788403
#     - Number of constraints for variable bounds: 788403
#     - Number of structural constraints: 420480
#   - Model solved!
#     - Termination status: OPTIMAL
#     - Objective value: 1.2205387507129153e6
#     - Objective breakdown:
#       - assets_fixed_cost_aggregated_vintage_method: 191995.2843629078
#       - assets_fixed_cost_compact_vintage_method: 0.0
#       - assets_investment_cost: 427479.7435955002
#       - flows_fixed_cost: 0.0
#       - flows_investment_cost: 0.0
#       - flows_operational_cost: 601063.7227550286
#       - storage_assets_energy_fixed_cost: 0.0
#       - storage_assets_energy_investment_cost: 0.0
#       - units_on_operational_cost: 0.0
#       - vintage_flows_operational_cost: 0.0

# %% [markdown]
# ### 2.2 Key results

# %% [markdown]
# #### Capacity

# %%
# initial wind capacity
filter(row -> occursin("wind", row.asset) && row.initial_units != 0.0, TIO.get_table(connection_vintage_standard, "asset_both"))
# Out:
# 3×6 DataFrame
#  Row │ asset   milestone_year  commission_year  decommissionable  initial_unit ⋯
#      │ String  Int32           Int32            Bool              Float64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ wind25            2030             2030             false           30. ⋯
#    2 │ wind25            2040             2040             false           30.
#    3 │ wind25            2050             2050             false           30.
#                                                                2 columns omitted

# %%
# invested capacity
filter(row -> occursin("wind", row.asset) && row.solution != 0.0, TIO.get_table(connection_vintage_standard, "var_assets_investment"))
# Out:
# 3×7 DataFrame
#  Row │ id     asset   milestone_year  investment_integer  capacity  investment ⋯
#      │ Int64  String  Int32           Bool                Float64   Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1  wind30            2030                true       1.0           1 ⋯
#    2 │     2  wind40            2040                true       1.0           1
#    3 │     3  wind50            2050                true       1.0           2
#                                                                2 columns omitted

# %% [markdown]
# #### Annual productions & total system cost

# %%
print_annual_total_prod(connection_vintage_standard, 2030, 2040, 2050)

total_cost = multiyear_vintage_standard.objective_value
println("Total system cost: $(round(total_cost/1000, digits=2)) Billion €")

inv_cost, fixed_om_cost, variable_om_cost = objective_terms_value(multiyear_vintage_standard, connection_vintage_standard)
println(
    "\t investment: $(round(inv_cost/1000, digits=2)) Billion € \n", 
    "\t fixed O&M: $(round(fixed_om_cost/1000, digits=2)) Billion € \n",
    "\t variable O&M: $(round(variable_om_cost/1000, digits=2)) Billion €"
)
println(
    "Total system cost ≈ investment + fixed O&M + variable O&M: ", 
    total_cost ≈ inv_cost + fixed_om_cost + variable_om_cost
)
# @assert total_cost ≈ inv_cost + fixed_om_cost + variable_om_cost
# Out:
# 2030s
# 	 wind prodution: 661.08 TWh p.a.
# 	 market supply: 317.83 TWh p.a.
# 2040s
# 	 wind prodution: 1507.38 TWh p.a.
# 	 market supply: 422.86 TWh p.a.
# 2050s
# 	 wind prodution: 1815.86 TWh p.a.
# 	 market supply: 427.39 TWh p.a.
# Total system cost: 1220.54 Billion €
# 	 investment: 427.48 Billion €
# 	 fixed O&M: 192.0 Billion €
# 	 variable O&M: 601.06 Billion €
# Total system cost ≈ investment + fixed O&M + variable O&M: true

# %% [markdown]
# ## Instance 3. Explicit technology vintage of units - compact method
#
# - Difference from **Instance 2**: `asset.csv` (only tha parameter `vintage_method`), `asset-commission.csv`, `asset-both`
# - In any milestone year, only the tech. vintage of the same year is available for investment (assumed with setting `vintage_method=compact_profiles` for "wind" `asset`)
# - Resulted investment in 2050 differ significantly from the no vintage case because the wind of 2020 vintage (wind commissioned in 2020, defined in `asset-commission.csv`) uses the default availability of `1.0` over the milestone year 2050 due to the lack of availability value is given for 2050 for this vintage (`availability-wind2020` records in `profiles-rep-periods.csv`, which is assigned to the wind commissioned in 2020 in `assets-profiles.csv`)

# %% [markdown]
# ### 3.1 Build and run the model instance

# %%
# Define and build the input output directories
input_dir = "model-instance-Tulipa/input-3-vintage-compact"
output_dir = joinpath(@__DIR__, "model-instance-Tulipa/output-3-vintage-compact")

# Always build a new result directory
rm(output_dir, force=true, recursive=true) 
mkdir(output_dir);

# Create the connection and prepare input data
connection_vintage_compact = DBInterface.connect(DuckDB.DB)
TIO.read_csv_folder(connection_vintage_compact, input_dir)
TEM.populate_with_defaults!(connection_vintage_compact)

# Run the model instance
multiyear_vintage_compact = TEM.run_scenario(
    connection_vintage_compact;
    optimizer_parameters = Dict("output_flag" => true), # TEM.default_parameters(HiGHS.Optimizer): Dict("output_flag" => false)
    output_folder = output_dir, 
    # model_file_name = joinpath(output_dir, "model.lp"),
    show_log=true,
    # To record solving time. 
    # Always run with this option in a new or restarted kernel to ensure the time is dedicated to this solve only.
    log_file = joinpath(@__DIR__, "model-instance-Tulipa/model-log_3-vintage-compact.txt")
)
# Out:
# Running HiGHS 1.14.0 (git hash: 7df0786de3): Copyright (c) 2026 under Apache 2.0 license terms
# Using BLAS: blastrampoline-5
# MIP has 341640 rows; 315363 cols; 683271 nonzeros; 3 integer variables (0 binary)
# Coefficient ranges:
#   Matrix  [3e-06, 1e+00]
#   Cost    [1e-03, 3e+03]
#   Bound   [1e+02, 2e+02]
#   RHS     [4e-04, 1e+02]
# Presolving model
# 26280 rows, 119287 cols, 171835 nonzeros 1s
# 25973 rows, 118980 cols, 171185 nonzeros 4s
# Presolve reductions: rows 25973(-315667); columns 118980(-196383); nonzeros 171185(-512086)
#
# Solving MIP model with:
#    25973 rows
#    118980 cols (0 binary, 3 integer, 0 implied int., 118977 continuous, 0 domain fixed)
#    171185 nonzeros
#
# Src: B => Branching; C => Central rounding; F => Feasibility pump; H => Heuristic;
#      I => Shifting; J => Feasibility jump; L => Sub-MIP; P => Empty MIP; R => Randomized rounding;
#      S => Solve LP; T => Evaluate node; U => Unbounded; X => User solution; Y => HiGHS solution;
#      Z => ZI Round; l => Trivial lower; p => Trivial point; u => Trivial upper; z => Trivial zero
#
#         Nodes      |    B&B Tree     |            Objective Bounds              |  Dynamic Constraints |       Work
# Src  Proc. InQueue |  Leaves   Expl. | BestBound       BestSol              Gap |   Cuts   InLp Confl. | LpIters     Time
#
#  J       0       0         0   0.00%   -inf            2119180.016705     Large        0      0      0         0     4.7s
#  R       0       0         0   0.00%   1220538.614382  1220538.750713     0.00%        0      0      0     43194    31.7s
#          1       0         1 100.00%   1220538.614382  1220538.750713     0.00%        0      0      0     43194    32.1s
#
# Solving report
#   Status            Optimal
#   Primal bound      1220538.75071
#   Dual bound        1220538.61438
#   Gap               1.1e-05% (tolerance: 0.01%)
#   P-D integral      21.6445690873
#   Solution status   feasible
#                     1220538.75071 (objective)
#                     0 (bound viol.)
#                     0 (int. viol.)
#                     0 (row viol.)
#   Timing            32.08
#   Max sub-MIP depth 0
#   Nodes             1
#   Repair LPs        0
#   LP iterations     43194
#                     0 (strong br.)
#                     0 (separation)
#                     0 (heuristics)
# LP has 341640 rows; 315363 cols; 683271 nonzeros
# Coefficient ranges:
#   Matrix  [3e-06, 1e+00]
#   Cost    [1e-03, 3e+03]
#   Bound   [1e+02, 2e+02]
#   RHS     [4e-04, 1e+02]
# Presolving model
# 19731 rows, 19730 cols, 19730 nonzeros 1s
# 0 rows, 0 cols, 0 nonzeros 1s
# Presolve reductions: rows 0(-341640); columns 0(-315363); nonzeros 0(-683271) - Reduced to empty
# Performed postsolve
# Solving the original LP from the solution after postsolve
# Using dual simplex solver
#   Iteration        Objective     Infeasibilities num(sum)
#           0     1.2205081684e+06 Pr: 1(58) 2.1s
#           2     1.2205387507e+06 Pr: 0(0) 2.2s
# Required 2 simplex iterations after postsolve
#
# Model status        : Optimal
# Simplex   iterations: 2
# Objective value     :  1.2205387507e+06
# P-D objective error :  5.0656443360e-13
# HiGHS run time      :          2.27
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#                                                                                                                                                          Time                    Allocations
#                                                                                                                                                 ───────────────────────   ────────────────────────
#                                                                Tot / % measured:                                                                      423h /   0.1%           21.7GiB /  73.9%
#
# Section                                                                                                                                 ncalls     time    %tot     avg     alloc    %tot      avg
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# solve_model!                                                                                                                                 3     894s   90.1%    298s   2.02GiB   12.6%   688MiB
#   total solver time                                                                                                                          3     894s   90.0%    298s   1.88GiB   11.7%   640MiB
# save_solution!                                                                                                                               3    41.1s    4.1%   13.7s   2.48GiB   15.5%   846MiB
#   compute_dual_variables                                                                                                                     3    26.5s    2.7%   8.82s   64.8MiB    0.4%  21.6MiB
# create_model!                                                                                                                                3    40.6s    4.1%   13.5s   9.63GiB   60.0%  3.21GiB
#   create_model                                                                                                                               3    40.6s    4.1%   13.5s   9.63GiB   60.0%  3.21GiB
#     add_expressions_to_constraints!                                                                                                          3    8.79s    0.9%   2.93s   1.75GiB   10.9%   597MiB
#       add_expression_terms_rep_period_constraints!                                                                                          21    4.98s    0.5%   237ms    822MiB    5.0%  39.1MiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method                                           3    1.54s    0.2%   515ms    859MiB    5.2%   286MiB
#       add_expression_terms_inter_period_storage_constraints!                                                                                 3    487ms    0.0%   162ms   18.1MiB    0.1%  6.02MiB
#       add_expression_terms_inter_period_constraints!                                                                                         6    380ms    0.0%  63.4ms   9.53MiB    0.1%  1.59MiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_compact_profiles_vintage_method                                     3    202ms    0.0%  67.4ms   65.8MiB    0.4%  21.9MiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method_non_investable_storage_with_binary        3   93.9ms    0.0%  31.3ms   96.0KiB    0.0%  32.0KiB
#       add_expression_terms_accumulated_storage_intra_period_constraints!                                                                     3   91.2ms    0.0%  30.4ms   94.9KiB    0.0%  31.6KiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_aggregated_vintage_method_investable_storage_with_binary            3   88.3ms    0.0%  29.4ms   95.8KiB    0.0%  31.9KiB
#       add_expression_terms_rep_period_constraints! for min_outgoing_flow_for_transport_flows_without_unit_commitment                         3   86.9ms    0.0%  29.0ms   95.7KiB    0.0%  31.9KiB
#       add_expression_terms_rep_period_constraints! for min_incoming_flow_for_transport_flows                                                 3   86.1ms    0.0%  28.7ms   94.6KiB    0.0%  31.5KiB
#       add_expression_terms_rep_period_constraints! for capacity_outgoing_compact_efficiencies_vintage_method                                 3   85.1ms    0.0%  28.4ms    784KiB    0.0%   261KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method_investable_storage_with_binary            3   83.0ms    0.0%  27.7ms   95.8KiB    0.0%  31.9KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method                                           3   82.5ms    0.0%  27.5ms   94.7KiB    0.0%  31.6KiB
#       add_expression_terms_rep_period_constraints! for capacity_incoming_aggregated_vintage_method_non_investable_storage_with_binary        3   82.3ms    0.0%  27.4ms   96.0KiB    0.0%  32.0KiB
#       add_expression_terms_rep_period_constraints! for min_outgoing_flow_for_transport_vintage_flows                                         3   53.3ms    0.0%  17.8ms   99.1KiB    0.0%  33.0KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method                                                           3   39.9ms    0.0%  13.3ms    703KiB    0.0%   234KiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method                                                           3   29.7ms    0.0%  9.90ms   9.26MiB    0.1%  3.09MiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method_non_investable_storage_with_binary                        3   29.4ms    0.0%  9.79ms   35.8KiB    0.0%  11.9KiB
#       attach units_on expression to min_output_flow_with_unit_commitment                                                                     3   28.9ms    0.0%  9.62ms   42.7KiB    0.0%  14.2KiB
#       attach is_charging expression to min_outgoing_flow_for_transport_flows_without_unit_commitment                                         3   27.0ms    0.0%  9.00ms   35.6KiB    0.0%  11.9KiB
#       attach is_charging expression to min_incoming_flow_for_transport_flows                                                                 3   24.5ms    0.0%  8.17ms   35.3KiB    0.0%  11.8KiB
#       attach units_on expression to max_output_flow_with_basic_unit_commitment                                                               3   23.9ms    0.0%  7.97ms   35.3KiB    0.0%  11.8KiB
#       attach is_charging expression to capacity_outgoing_compact_profiles_vintage_method                                                     3   23.2ms    0.0%  7.74ms    446KiB    0.0%   149KiB
#       attach units_on expression to max_ramp_with_unit_commitment                                                                            3   23.1ms    0.0%  7.70ms   35.0KiB    0.0%  11.7KiB
#       attach is_charging expression to capacity_outgoing_aggregated_vintage_method_investable_storage_with_binary                            3   22.9ms    0.0%  7.65ms   35.7KiB    0.0%  11.9KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method_non_investable_storage_with_binary                        3   21.1ms    0.0%  7.05ms   35.8KiB    0.0%  11.9KiB
#       attach is_charging expression to capacity_incoming_aggregated_vintage_method_investable_storage_with_binary                            3   21.0ms    0.0%  7.01ms   35.7KiB    0.0%  11.9KiB
#     add_capacity_constraints!                                                                                                                3    6.64s    0.7%   2.21s   2.43GiB   15.1%   829MiB
#     add_flow_variables!                                                                                                                      3    5.42s    0.5%   1.81s   2.30GiB   14.3%   784MiB
#     add_operational_cost_expressions!                                                                                                        3    4.48s    0.5%   1.49s   0.95GiB    5.9%   325MiB
#     add_consumer_constraints!                                                                                                                3    3.03s    0.3%   1.01s   1.17GiB    7.3%   400MiB
#     add_objective!                                                                                                                           3    3.01s    0.3%   1.00s    579MiB    3.5%   193MiB
#     add_ramping_constraints!                                                                                                                 3    587ms    0.1%   196ms   41.9MiB    0.3%  14.0MiB
#     add_investment_variables!                                                                                                                3    388ms    0.0%   129ms   31.9MiB    0.2%  10.6MiB
#     add_decommission_variables!                                                                                                              3    246ms    0.0%  82.0ms   25.5MiB    0.2%  8.50MiB
#     create_multi_year_expressions!                                                                                                           3    243ms    0.0%  80.9ms   8.77MiB    0.1%  2.92MiB
#     prepare_objective_tables!                                                                                                                3    170ms    0.0%  56.8ms   3.37MiB    0.0%  1.12MiB
#     add_storage_constraints!                                                                                                                 3    159ms    0.0%  52.9ms   8.64MiB    0.1%  2.88MiB
#     add_storage_variables!                                                                                                                   3   56.9ms    0.0%  19.0ms   2.62MiB    0.0%   895KiB
#     get_model_parameters!                                                                                                                    3   51.3ms    0.0%  17.1ms   2.39MiB    0.0%   814KiB
#     add_dc_power_flow_constraints!                                                                                                           3   48.1ms    0.0%  16.0ms   2.08MiB    0.0%   710KiB
#     add_shut_down_upper_bound_constraints!                                                                                                   3   42.1ms    0.0%  14.0ms   1.32MiB    0.0%   449KiB
#     add_energy_constraints!                                                                                                                  3   34.3ms    0.0%  11.4ms   1.31MiB    0.0%   448KiB
#     add_flows_relationships_constraints!                                                                                                     3   34.0ms    0.0%  11.3ms   1.32MiB    0.0%   450KiB
#     add_storage_expressions!                                                                                                                 3   23.4ms    0.0%  7.78ms    694KiB    0.0%   231KiB
#     add_conditional_value_at_risk_variables!                                                                                                 3   20.7ms    0.0%  6.90ms   1.29MiB    0.0%   442KiB
#     add_vintage_flow_sum_constraints!                                                                                                        3   20.3ms    0.0%  6.76ms    679KiB    0.0%   226KiB
#     add_transport_constraints!                                                                                                               3   19.8ms    0.0%  6.60ms    694KiB    0.0%   231KiB
#     add_vintage_flow_variables!                                                                                                              3   19.2ms    0.0%  6.40ms    676KiB    0.0%   225KiB
#     add_investment_group_constraints!                                                                                                        3   19.2ms    0.0%  6.39ms    677KiB    0.0%   226KiB
#     add_uc_logic_constraints!                                                                                                                3   18.4ms    0.0%  6.13ms    691KiB    0.0%   230KiB
#     add_start_up_upper_bound_constraints!                                                                                                    3   17.7ms    0.0%  5.91ms    681KiB    0.0%   227KiB
#     add_conversion_constraints!                                                                                                              3   14.7ms    0.0%  4.90ms    672KiB    0.0%   224KiB
#     add_unit_commitment_variables!                                                                                                           3   12.1ms    0.0%  4.02ms    666KiB    0.0%   222KiB
#     add_power_flow_variables!                                                                                                                3   11.2ms    0.0%  3.74ms    665KiB    0.0%   222KiB
#     add_scenario_tail_excess_expressions!                                                                                                    3   5.24ms    0.0%  1.75ms   10.0KiB    0.0%  3.34KiB
#     add_scenario_tail_excess_constraints!                                                                                                    3   1.77ms    0.0%   589μs   1.59KiB    0.0%     544B
#     add_start_up_and_shut_down_variables!                                                                                                    3    146μs    0.0%  48.6μs   12.7KiB    0.0%  4.22KiB
# create EnergyProblem from connection                                                                                                         3    14.6s    1.5%   4.85s   1.92GiB   11.9%   654MiB
#   create_internal_structure                                                                                                                  3    12.9s    1.3%   4.30s   1.87GiB   11.6%   638MiB
#     create_lowest_resolution_table                                                                                                           3    6.02s    0.6%   2.01s   1.73GiB   10.8%   589MiB
#       append t_lowest_all_flows rows                                                                                                         3    3.85s    0.4%   1.28s    885MiB    5.4%   295MiB
#       append t_lowest_all rows                                                                                                               3    2.09s    0.2%   698ms    883MiB    5.4%   294MiB
#       append t_lowest_flows_relationship rows                                                                                                3   2.98ms    0.0%   994μs   7.55KiB    0.0%  2.52KiB
#       append t_lowest_flows_conversion_balance rows                                                                                          3   2.12ms    0.0%   707μs   7.59KiB    0.0%  2.53KiB
#     create_highest_resolution_table                                                                                                          3    2.01s    0.2%   669ms   24.9KiB    0.0%  8.31KiB
#     create_merged_tables                                                                                                                     3    1.96s    0.2%   652ms   20.5KiB    0.0%  6.84KiB
#     validate data                                                                                                                            3    1.92s    0.2%   639ms    121MiB    0.7%  40.3MiB
#       no duplicate rows                                                                                                                      3    369ms    0.0%   123ms   19.2MiB    0.1%  6.39MiB
#       valid schema's oneOf constraints                                                                                                       3    256ms    0.0%  85.2ms   21.0MiB    0.1%  7.01MiB
#       consumer unit commitment used as bids has right data                                                                                   3    233ms    0.0%  77.8ms   32.0MiB    0.2%  10.7MiB
#       has all tables and columns                                                                                                             3    204ms    0.0%  68.0ms   2.89MiB    0.0%  0.96MiB
#       stochastic scenario probabilities sum to 1                                                                                             3    144ms    0.0%  48.0ms   8.71MiB    0.1%  2.90MiB
#       group consistency between tables                                                                                                       3    131ms    0.0%  43.6ms   13.3MiB    0.1%  4.44MiB
#       data consistency for aggregated vintage method                                                                                         3    118ms    0.0%  39.3ms   4.42MiB    0.0%  1.47MiB
#       model_parameters discount_year is valid                                                                                                3   65.9ms    0.0%  22.0ms   3.07MiB    0.0%  1.02MiB
#       consistency between flow_commission and asset_both                                                                                     3   63.2ms    0.0%  21.1ms   2.00MiB    0.0%   682KiB
#       consistency between asset_commission and asset_both                                                                                    3   56.4ms    0.0%  18.8ms   2.42MiB    0.0%   828KiB
#       check DC OPF data                                                                                                                      3   55.1ms    0.0%  18.4ms   2.04MiB    0.0%   698KiB
#       consumer assets use the aggregated vintage method                                                                                      3   39.3ms    0.0%  13.1ms   1.53MiB    0.0%   523KiB
#       commodity_price profiles require commodity_price > 0                                                                                   3   38.3ms    0.0%  12.8ms   1.59MiB    0.0%   542KiB
#       investable storage assets using binary method should have investment limit > 0                                                         3   38.3ms    0.0%  12.8ms   2.02MiB    0.0%   691KiB
#       flow_both only contain transport flows                                                                                                 3   33.9ms    0.0%  11.3ms   1.78MiB    0.0%   609KiB
#       consistency between investable and asset_both                                                                                          3   32.2ms    0.0%  10.7ms   1.37MiB    0.0%   469KiB
#       only transport flows are investable                                                                                                    3   32.1ms    0.0%  10.7ms   1.29MiB    0.0%   441KiB
#       model_parameters has exactly one row                                                                                                   3   8.02ms    0.0%  2.67ms   96.1KiB    0.0%  32.0KiB
#     create_unrolled_partition_tables                                                                                                         3    827ms    0.1%   276ms   16.5MiB    0.1%  5.50MiB
#   prepare_profiles_structure                                                                                                                 3    609ms    0.1%   203ms   45.8MiB    0.3%  15.3MiB
#   compute_constraints_indices                                                                                                                3    549ms    0.1%   183ms   1.95MiB    0.0%   665KiB
#   compute_variables_indices                                                                                                                  3    486ms    0.0%   162ms    118KiB    0.0%  39.5KiB
# export_solution_to_csv_files                                                                                                                 3    2.10s    0.2%   700ms   5.43MiB    0.0%  1.81MiB
# ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# EnergyProblem:
#   - Model created!
#     - Number of variables: 315363
#     - Number of constraints for variable bounds: 315363
#     - Number of structural constraints: 341640
#   - Model solved!
#     - Termination status: OPTIMAL
#     - Objective value: 1.2205387507129153e6
#     - Objective breakdown:
#       - assets_fixed_cost_aggregated_vintage_method: 0.0
#       - assets_fixed_cost_compact_vintage_method: 191995.2843629078
#       - assets_investment_cost: 427479.7435955002
#       - flows_fixed_cost: 0.0
#       - flows_investment_cost: 0.0
#       - flows_operational_cost: 601063.7227553019
#       - storage_assets_energy_fixed_cost: 0.0
#       - storage_assets_energy_investment_cost: 0.0
#       - units_on_operational_cost: 0.0
#       - vintage_flows_operational_cost: 0.0

# %% [markdown]
# ### 3.2 Key results

# %% [markdown]
# #### Capacity

# %% [markdown]
# - Units built in different years are explicitly listed,
# - meaning that their corresponding profiles are also considered.

# %%
# initial wind capacity
filter(row -> row.asset=="wind" && row.initial_units != 0, TIO.get_table(connection_vintage_compact, "asset_both"))
# Out:
# 3×6 DataFrame
#  Row │ asset   milestone_year  commission_year  decommissionable  initial_unit ⋯
#      │ String  Int32           Int32            Bool              Float64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ wind              2030             2025             false           30. ⋯
#    2 │ wind              2040             2025             false           30.
#    3 │ wind              2050             2025             false           30.
#                                                                2 columns omitted

# %%
# invested capacity of the wind commissioned in the milestone year
filter(row -> row.asset=="wind", TIO.get_table(connection_vintage_compact, "var_assets_investment"))
# Out:
# 3×7 DataFrame
#  Row │ id     asset   milestone_year  investment_integer  capacity  investment ⋯
#      │ Int64  String  Int32           Bool                Float64   Float64    ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │     1  wind              2030                true       1.0           1 ⋯
#    2 │     2  wind              2040                true       1.0           1
#    3 │     3  wind              2050                true       1.0           2
#                                                                2 columns omitted

# %% [markdown]
# #### Annual productions & total system cost

# %%
print_annual_total_prod(connection_vintage_compact, 2030, 2040, 2050)

total_cost = multiyear_vintage_compact.objective_value
println("Total system cost: $(round(total_cost/1000, digits=2)) Billion €")

inv_cost, fixed_om_cost, variable_om_cost = objective_terms_value(multiyear_vintage_compact, connection_vintage_compact)
println(
    "\t investment: $(round(inv_cost/1000, digits=2)) Billion € \n", 
    "\t fixed O&M: $(round(fixed_om_cost/1000, digits=2)) Billion € \n",
    "\t variable O&M: $(round(variable_om_cost/1000, digits=2)) Billion €"
)
println(
    "Total system cost ≈ investment + fixed O&M + variable O&M: ", 
    total_cost ≈ inv_cost + fixed_om_cost + variable_om_cost
)
# @assert total_cost ≈ inv_cost + fixed_om_cost + variable_om_cost
# Out:
# 2030s
# 	 wind prodution: 661.08 TWh p.a.
# 	 market supply: 317.83 TWh p.a.
# 2040s
# 	 wind prodution: 1507.38 TWh p.a.
# 	 market supply: 422.86 TWh p.a.
# 2050s
# 	 wind prodution: 1815.86 TWh p.a.
# 	 market supply: 427.39 TWh p.a.
# Total system cost: 1220.54 Billion €
# 	 investment: 427.48 Billion €
# 	 fixed O&M: 192.0 Billion €
# 	 variable O&M: 601.06 Billion €
# Total system cost ≈ investment + fixed O&M + variable O&M: true
